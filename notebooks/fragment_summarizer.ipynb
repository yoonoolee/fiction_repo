# %% [markdown]
# # BART Summarizer Testing
#
# Test BART summarization for compressing 100+ word text into 10-40 word summaries.

# %% [markdown]
# ## Setup

# %%
from transformers import pipeline
import warnings
warnings.filterwarnings('ignore')

print("✓ Imports loaded")
# Out:
# ✓ Imports loaded

# %% [markdown]
# ## Load BART, T5, Pegasus Models

# %%
bart_summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
t5_summarizer = pipeline("summarization", model="t5-base")
pegasus_summarizer = pipeline("summarization", model="google/pegasus-cnn_dailymail")

print("✓ Model loaded")
# Out:
# Device set to use mps:0
# python(64704) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use mps:0
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-cnn_dailymail and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %% [markdown]
# ## Test Summarization
#
# Put your text in the `text` variable and run the cell to see the summary.

# %%
# Put your text here
text = """
Thanos arrives and he's much bigger and much more terrifying than Peter expected. They subdue him in seconds, but it's a near thing.

Peter puts his hands over the jewels slotted into place on Thanos' gauntlet and finds his grip just near the biggest one set below the four others. The orange-gold one. It fairly thrums with power, like Tony's arc reactor, pushing out unseen waves of heat that run along the length of his arm. He starts to pull.

Something cracks beneath his hand.

There's a weight in his hand that disappears the second it lands there. Something bright, something gold, he thinks, but he can't think of why it would be gold. It isn't in his hand when he looks, so whatever it is, he must've dropped it. Thanos must have invested in some pretty cheap metal for this gauntlet.
"""

# %% [markdown]
# ## Test with all models

# %%
print("\n" + "="*80)
print(f"({len(text.split())} words)")
print("="*80)
print(f"\nOriginal:\n{text.strip()}\n")
# Out:
# ...
# (142 words)
# ...
#
# Original:
# Thanos arrives and he's much bigger and much more terrifying than Peter expected. They subdue him in seconds, but it's a near thing.
#
# Peter puts his hands over the jewels slotted into place on Thanos' gauntlet and finds his grip just near the biggest one set below the four others. The orange-gold one. It fairly thrums with power, like Tony's arc reactor, pushing out unseen waves of heat that run along the length of his arm. He starts to pull.
#
# Something cracks beneath his hand.
#
# There's a weight in his hand that disappears the second it lands there. Something bright, something gold, he thinks, but he can't think of why it would be gold. It isn't in his hand when he looks, so whatever it is, he must've dropped it. Thanos must have invested in some pretty cheap metal for this gauntlet.

# %%
# BART
bart_result = summarizer(text, max_length=50, min_length=15, length_penalty=2.0, do_sample=False)
bart_summary = bart_result[0]['summary_text']
print(f"\n📝 BART ({len(bart_summary.split())} words):")
print(bart_summary)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # BART
# ----> 2 bart_result = summarizer(text, max_length=50, min_length=15, length_penalty=2.0, do_sample=False)
#       3 bart_summary = bart_result[0]['summary_text']
#       4 print(f"\n📝 BART ({len(bart_summary.split())} words):")
#
# File /opt/anaconda3/lib/python3.13/site-packages/transformers/pipelines/text2text_generation.py:303, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     279 def __call__(self, *args, **kwargs):
#     280     r"""
#     281     Summarize the text(s) given as inputs.
#     282
#    (...)
#     301           ids of the summary.
#     302     """
# --> 303     return super().__call__(*args, **kwargs)
#
# ...

# %%
# T5
t5_result = t5_summarizer("summarize: " + text, max_length=60, min_length=15, do_sample=False)
t5_summary = t5_result[0]['summary_text']
print(f"\n📝 T5 ({len(t5_summary.split())} words):")
print(t5_summary)

# %%
# Pegasus
pegasus_result = pegasus_summarizer(text, max_length=60, min_length=15, do_sample=False)
pegasus_summary = pegasus_result[0]['summary_text']
print(f"\n📝 Pegasus ({len(pegasus_summary.split())} words):")
print(pegasus_summary)
print()

# %% [markdown]
# ## Compare All Models on All Examples

# %%
# Use one of the examples or paste your own
text = example1  # Change to example2, example3, or your own text

print(f"Original ({len(text.split())} words):")
print(text.strip())
print("\n" + "="*80 + "\n")

# BART
bart_result = summarizer(text, max_length=60, min_length=15, do_sample=False)
bart_summary = bart_result[0]['summary_text']
print(f"BART ({len(bart_summary.split())} words):")
print(bart_summary)
print("\n" + "-"*80 + "\n")

# T5
t5_result = t5_summarizer("summarize: " + text, max_length=60, min_length=15, do_sample=False)
t5_summary = t5_result[0]['summary_text']
print(f"T5 ({len(t5_summary.split())} words):")
print(t5_summary)
print("\n" + "-"*80 + "\n")

# Pegasus
pegasus_result = pegasus_summarizer(text, max_length=60, min_length=15, do_sample=False)
pegasus_summary = pegasus_result[0]['summary_text']
print(f"Pegasus ({len(pegasus_summary.split())} words):")
print(pegasus_summary)

# %% [markdown]
# ## Compare All Three Models
#
# Run the same text through all three models to compare outputs side-by-side.

# %%
# Put your text here
text = """
Paste your text here
"""

print(f"Input: {len(text.split())} words")
print(f"\nOriginal text:\n{text}")
print("\n" + "="*80 + "\n")

result = pegasus_summarizer(text, 
                            max_length=60,
                            min_length=15,
                            do_sample=False)

summary = result[0]['summary_text']
print(f"Pegasus Summary ({len(summary.split())} words):\n{summary}")

# %% [markdown]
# ## Test Pegasus Summarization

# %%
print("Loading Pegasus model...")
pegasus_summarizer = pipeline("summarization", model="google/pegasus-cnn_dailymail")
print("✓ Pegasus model loaded")

# %% [markdown]
# ## Load Pegasus Model

# %%
# Put your text here
text = """
Paste your text here
"""

print(f"Input: {len(text.split())} words")
print(f"\nOriginal text:\n{text}")
print("\n" + "="*80 + "\n")

# T5 requires "summarize: " prefix
result = t5_summarizer("summarize: " + text, 
                       max_length=60,
                       min_length=15,
                       do_sample=False)

summary = result[0]['summary_text']
print(f"T5 Summary ({len(summary.split())} words):\n{summary}")

# %% [markdown]
# ## Test T5 Summarization

# %%
print("Loading T5 model...")
t5_summarizer = pipeline("summarization", model="t5-base")
print("✓ T5 model loaded")
